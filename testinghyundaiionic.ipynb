3A%20home%3A%20ioniq%205,2,2,796,1426,796,1440,900,2,P; ipe_s=5edbc2b5-a0e1-0c28-6ce7-ac4536161c30; _aeaid=03f2e68f-7059-4cf1-a4f3-275e4edcecfe; IPE_LandingTime=1655137459757; ipe.322.pageViewedCount=1; ipe.322.pageViewedDay=164; ipe_322_fov={"numberOfVisits":1,"sessionId":"5edbc2b5-a0e1-0c28-6ce7-ac4536161c30","expiry":"2022-07-13T16:24:19.782Z","lastVisit":"2022-06-13T16:24:19.782Z"}; OptanonAlertBoxClosed=2022-06-13T16:24:20.333Z; OptanonConsent=isGpcEnabled=0&datestamp=Mon+Jun+13+2022+12:24:20+GMT-0400+(Eastern+Daylight+Time)&version=6.30.0&isIABGlobal=false&hosts=&consentId=a38944e6-6bf1-490c-adfa-8737a9dd1109&interactionCount=1&landingPath=NotLandingPage&groups=C0003:1,C0001:1,C0002:1,BG18:1,C0004:1; aelastsite=cPse/4ilq18K5PO0nmpeINtYqinYaz9cECulfv7mhMaUn0ylDJlpA0ixb3hz4I9T; aelreadersettings={"c_big":0,"rg":0,"memph":0,"contrast_setting":0,"colorshift_setting":0,"text_size_setting":0,"space_setting":0,"font_setting":0,"k":0,"k_disable_default":0,"hlt":0,"disable_animations":0,"display_alt_desc":0}; aeatstartmessage=true; s_ppv=h%3A%20vehicles%3A%20home%3A%20ioniq%205,2,2,796,1426,281,1440,900,2,P; utag_main=v_id:01815de11c0e001a49f3317530770507900360710093c$_sn:1$_se:5$_ss:0$_st:1655139277577$ses_id:1655137442839;exp-session$_pn:1;exp-session$vapi_domain:hyundaiusa.com; s_sq=[[B]]',
    'cookie': 'check=true;',      
    'referer':'https://www.hyundaiusa.com/us/en/vehicles/ioniq-5.json'}

# %%
response = requests.get(request_url,headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
available = list()
for item in response.json()['data'][0]['dealerInfo']:
    if item['vehicles']!=None:
        available.append(item)

# %%
available[0]
# Out:
# {'dealerCd': 'MD013',
#  'dealerNm': 'Ideal Hyundai',
#  'dealerEmail': 'mmcgoldrick@idealcarstrucks.com',
#  'dealerUrl': 'www.idealhyundai.com',
#  'address1': '5871 Urbana Pike',
#  'address2': '',
#  'city': 'Frederick',
#  'state': 'MD',
#  'zip': '21701',
#  'phone': '301-663-3121',
#  'fax': '301-663-6260',
#  'region': 'MA',
#  'latitude': 39.3924102,
#  'longitude': -77.4056842,
#  'distance': 125.79,
#  'shopperAssurance': 'Y',
#  'IsPMADealer': 0,
#  'vehicles': [{'vin': 'KM8KRDAF7NU076139',
#    'modelNm': 'Ioniq 5',
#    'trimDesc': 'LIMITED',
#    'modelCd': '50462AEZ',
#    'price': '$56,260.00',
#    'exteriorColorCd': 'M9U',
#    'interiorColorCd': 'NNB',
#    'drivetrainDesc': 'ALL WHEEL DRIVE',
#    'transmissionDesc': 'AUTO',
#    'TotalPackages': 0,
#    'TotalOptions': 0,
#    'packages': None,
#    'colors': [{'SAPExterioColorCode': 'M9U',
#      'ExtColorLongDesc': 'DIGITAL TEAL',
#      '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/digital-teal/360/',
#        'PackageID': 'P1'}]}],
#    'PlannedDeliveryDate': '2022-03-17T15:11:00',
#    'inventoryStatus': 'DS'}]}

# %%
import pandas as pd
all_vehicles = list()
for x in available:
    dealerNm = x['dealerNm']
    # grab dealer characteristics
    dealer_dict = [{k:x[k] for k in ['dealerNm', 'city','state','distance']}]
    vehicles = list()
    for y in x['vehicles']:
        vehicles.append({key:y[key] for key in [#'vin',
            'modelNm','trimDesc','price','exteriorColorCd','colors','PlannedDeliveryDate', 'inventoryStatus', 'drivetrainDesc']})
    dealer_frame = pd.DataFrame(dealer_dict)
    vehicle_frame = pd.DataFrame(vehicles)
    vehicle_frame['dealerNm'] = dealerNm
    all_vehicles.append(dealer_frame.merge(vehicle_frame,on='dealerNm'))

# %%
len(available)
# Out:
# 144

# %%
results = pd.concat(all_vehicles).reset_index(drop=True)
results[#(results['exteriorColorCd']=='M9U') &
    (results['trimDesc']=='SEL')
        & (results['drivetrainDesc']=='REAR WHEEL DRIVE')]
# Out:
#                             dealerNm              city state  distance  \
# 10     Capital Hyundai Of Greensboro        Greensboro    NC    158.28
# 14                   Parkway Hyundai        Wilmington    NC    230.17
# 17              Bob Mayberry Hyundai            Monroe    NC    244.14
# 18              Bob Mayberry Hyundai            Monroe    NC    244.14
# 19              Bob Mayberry Hyundai            Monroe    NC    244.14
# 24           South Charlotte Hyundai         Charlotte    NC    251.23
# 36                    Circle Hyundai        Shrewsbury    NJ    266.14
# 52                   Paramus Hyundai           Paramus    NJ    296.61
# 148               Southtowne Hyundai         Riverdale    GA    476.10
# 173                  Wallace Hyundai            Stuart    FL    735.73
# 179            Coconut Creek Hyundai     Coconut Creek    FL    794.28
# 181                  Kendall Hyundai             Miami    FL    841.34
# 183              Chris Crain Hyundai            Conway    AR    844.17
# 184        Crain Hyundai Little Rock       Little Rock    AR    851.06
# 189                    Tulsa Hyundai             Tulsa    OK   1018.23
# 190                    Tulsa Hyundai             Tulsa    OK   1018.23
# 191                    Tulsa Hyundai             Tulsa    OK   1018.23
# 192                    Tulsa Hyundai             Tulsa    OK   1018.23
# 193                    Tulsa Hyundai             Tulsa    OK   1018.23
# 207                   Edmond Hyundai            Edmond    OK   1111.97
# 208                   Edmond Hyundai            Edmond    OK   1111.97
# 209                   Edmond Hyundai            Edmond    OK   1111.97
# 214            Bob Stallings Hyundai            Dallas    TX   1140.13
# 215            Bob Stallings Hyundai            Dallas    TX   1140.13
# 216            Bob Stallings Hyundai            Dallas    TX   1140.13
# 217            Bob Stallings Hyundai            Dallas    TX   1140.13
# 218            Bob Stallings Hyundai            Dallas    TX   1140.13
# 228               Hyundai Of Greeley           Greeley    CO   1467.58
# 239  Phil Long Hyundai Of Motor City  Colorado Springs    CO   1477.83
# 242               Foundation Hyundai       Westminster    CO   1483.06
{'SAPExterioColorCode': 'M9U', 'ExtColorLongD...  2022-06-10T07:00:00
# 14   [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-05-25T19:59:00
# 17   [{'SAPExterioColorCode': 'M9U', 'ExtColorLongD...  2022-06-22T20:07:38
# 18   [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-06-23T20:00:31
# 19   [{'SAPExterioColorCode': 'U3P', 'ExtColorLongD...  2022-06-23T00:36:09
# 24   [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-05-25T19:59:00
# 36   [{'SAPExterioColorCode': 'M9U', 'ExtColorLongD...  2022-06-12T07:00:00
# 52   [{'SAPExterioColorCode': 'M9U', 'ExtColorLongD...  2022-06-09T07:00:00
# 148  [{'SAPExterioColorCode': 'C5G', 'ExtColorLongD...  2022-06-30T10:54:00
# 173  [{'SAPExterioColorCode': 'SAW', 'ExtColorLongD...  2022-06-07T19:59:00
# 179  [{'SAPExterioColorCode': 'SAW', 'ExtColorLongD...  2022-06-07T19:59:00
# 181  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-03-20T00:19:00
# 183  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-23T07:00:00
# 184  [{'SAPExterioColorCode': 'SAW', 'ExtColorLongD...  2022-06-19T07:00:00
# 189  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-22T07:00:00
# 190  [{'SAPExterioColorCode': 'M9U', 'ExtColorLongD...  2022-06-25T07:00:00
# 191  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-25T07:00:00
# 192  [{'SAPExterioColorCode': 'U3P', 'ExtColorLongD...  2022-06-22T07:00:00
# 193  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-22T07:00:00
# 207  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-24T07:00:00
# 208  [{'SAPExterioColorCode': 'SAW', 'ExtColorLongD...  2022-06-24T07:00:00
# 209  [{'SAPExterioColorCode': 'C5G', 'ExtColorLongD...  2022-06-24T07:00:00
# 214  [{'SAPExterioColorCode': 'SAW', 'ExtColorLongD...  2022-06-23T07:00:00
# 215  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-22T07:00:00
# 216  [{'SAPExterioColorCode': 'U3P', 'ExtColorLongD...  2022-06-23T07:00:00
# 217  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-22T07:00:00
# 218  [{'SAPExterioColorCode': 'C5G', 'ExtColorLongD...  2022-06-21T07:00:00
# 228  [{'SAPExterioColorCode': 'SAW', 'ExtColorLongD...  2022-06-27T12:16:00
# 239  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-21T07:00:00
# 242  [{'SAPExterioColorCode': 'M9U', 'ExtColorLongD...  2022-06-14T07:00:00
# 243  [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-06-13T07:00:00
# 247  [{'SAPExterioColorCode': 'C5G', 'ExtColorLongD...  2022-06-14T07:00:00
# 257  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-10T07:00:00
# 260  [{'SAPExterioColorCode': 'M9U', 'ExtColorLongD...  2022-07-13T05:01:00
# 273  [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-07-12T05:01:00
# 274  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-07-12T05:01:00
# 275  [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-07-15T05:01:00
# 276  [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-07-15T05:01:00
# 288  [{'SAPExterioColorCode': 'MZH', 'ExtColorLongD...  2022-06-24T20:53:57
# 289  [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-05-21T19:25:00
# 318  [{'SAPExterioColorCode': 'U3P', 'ExtColorLongD...  2022-06-29T03:11:44
# 331  [{'SAPExterioColorCode': 'C5G', 'ExtColorLongD...  2022-06-23T23:38:04
# 344  [{'SAPExterioColorCode': 'T5R', 'ExtColorLongD...  2022-06-14T07:00:00
# 346  [{'SAPExterioColorCode': 'U3P', 'ExtColorLongD...  2022-05-15T16:58:00
#
#     inventoryStatus    drivetrainDesc
# 10               DS  REAR WHEEL DRIVE
# 14               DS  REAR WHEEL DRIVE
# 17               TN  REAR WHEEL DRIVE
# 18               TN  REAR WHEEL DRIVE
# 19               TN  REAR WHEEL DRIVE
# 24               DS  REAR WHEEL DRIVE
# 36               DS  REAR WHEEL DRIVE
# 52               DS  REAR WHEEL DRIVE
# 148              DS  REAR WHEEL DRIVE
# 173              DS  REAR WHEEL DRIVE
# 179              IT  REAR WHEEL DRIVE
# 181              DS  REAR WHEEL DRIVE
# 183              IR  REAR WHEEL DRIVE
# 184              IR  REAR WHEEL DRIVE
# 189              IR  REAR WHEEL DRIVE
# 190              IR  REAR WHEEL DRIVE
# 191              IR  REAR WHEEL DRIVE
# 192              IR  REAR WHEEL DRIVE
# 193              IR  REAR WHEEL DRIVE
# 207              IR  REAR WHEEL DRIVE
# 208              IR  REAR WHEEL DRIVE
# 209              IR  REAR WHEEL DRIVE
# 214              IR  REAR WHEEL DRIVE
# 215              IR  REAR WHEEL DRIVE
# 216              IR  REAR WHEEL DRIVE
# 217              IR  REAR WHEEL DRIVE
# 218              IR  REAR WHEEL DRIVE
# 228              DS  REAR WHEEL DRIVE
# 239              IR  REAR WHEEL DRIVE
# 242              DS  REAR WHEEL DRIVE
# 243              IR  REAR WHEEL DRIVE
# 247              IR  REAR WHEEL DRIVE
# 257              DS  REAR WHEEL DRIVE
# 260              DS  REAR WHEEL DRIVE
# 273              DS  REAR WHEEL DRIVE
# 274              DS  REAR WHEEL DRIVE
# 275              DS  REAR WHEEL DRIVE
# 276              DS  REAR WHEEL DRIVE
# 288              TN  REAR WHEEL DRIVE
# 289              DS  REAR WHEEL DRIVE
# 318              TN  REAR WHEEL DRIVE
# 331              TN  REAR WHEEL DRIVE
# 344              IT  REAR WHEEL DRIVE
# 346              DS  REAR WHEEL DRIVE

# %%
import numpy as np
results['colors'].tolist()
# Out:
# [[{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
# ...
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'M9U',
#    'ExtColorLongDesc': 'DIGITAL TEAL',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/digital-teal/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/limited/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se-std-range/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'MZH',
#    'ExtColorLongDesc': 'PHANTOM BLACK',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/phantom-black/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'SAW',
#    'ExtColorLongDesc': 'ATLAS WHITE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/atlas-white/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'T5R',
#    'ExtColorLongDesc': 'SHOOTING STAR',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/shooting-star/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'C5G',
#    'ExtColorLongDesc': 'CYBER GRAY',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/se/exterior/base/cyber-gray/360/',
#      'PackageID': 'P1'}]}],
#  [{'SAPExterioColorCode': 'U3P',
#    'ExtColorLongDesc': 'LUCID BLUE',
#    '360ImagePaths': [{'ImagePath': '/content/dam/hyundai/us/com/image/2022/ioniq5/sel/exterior/base/lucid-blue/360/',
#      'PackageID': 'P1'}]}]]

# %%
len(available[1]['vehicles'])
# Out:
# 1
